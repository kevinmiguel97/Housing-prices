# %% [markdown]
# # US housing prices model

# %% [markdown]
# ## 0. Importing libraries

# %%
import numpy as np
import pandas as pd

# FRED API
from fredapi import Fred
# Importing fred API key
path = 'C:\\Users\\kevmi\\OneDrive\\Documentos\\Github Proyects\\API Keys\\FRED\\fred_api_key.txt'
with open(path, 'r') as f:
    lines = f.readlines()
fred_key = lines[0]

# %% [markdown]
# ### Creating FRED object

# %%
fred = Fred(api_key=fred_key)
fred

# %% [markdown]
# ## 1. Extracting series from FRED and reading Zillow data

# %% [markdown]
# ### Function that retrieves FRED series with ID of the series

# %%
def get_data(series_id, initial_date = '1947-01-01', final_date = '2022-07-01'):
    fred.search(str(series_id), order_by='popularity')
    frame_search = fred.get_series(series_id=str(series_id), observation_start=initial_date,
                                observation_end=final_date)
    frame_id = pd.DataFrame(frame_search)
    return frame_id

# %% [markdown]
# ### Importing data

# %%
# Consumer Price Index
df_cpi = get_data(series_id='CPIAUCSL', initial_date='1947-01-01', final_date='2022-07-01')
# Rental Vacancy Rate in the United States
df_rvr = get_data(series_id='RRVRUSQ156N', initial_date='1956-01-01', final_date='2022-04-01')
# Mortgage interest rate
df_mir = get_data(series_id='MORTGAGE30US', initial_date='1956-01-01', final_date='2022-04-01')
# Median sale price for US houses
df_median_price = pd.read_csv('data/Metro_median_sale_price_uc_sfrcondo_week.csv')
# Zillow home value index
df_zillow = pd.read_csv('data/Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_month.csv')

# %%
fred.search('Mortgage interest rates', order_by='popularity')
# Out:
#                                           id realtime_start realtime_end  \
# series id
# MORTGAGE30US                    MORTGAGE30US     2022-09-09   2022-09-09
# FEDFUNDS                            FEDFUNDS     2022-09-09   2022-09-09
# BAMLH0A0HYM2                    BAMLH0A0HYM2     2022-09-09   2022-09-09
# BAMLH0A0HYM2EY                BAMLH0A0HYM2EY     2022-09-09   2022-09-09
# DFF                                      DFF     2022-09-09   2022-09-09
# BAMLC0A0CM                        BAMLC0A0CM     2022-09-09   2022-09-09
# MORTGAGE15US                    MORTGAGE15US     2022-09-09   2022-09-09
# BAMLHE00EHYIOAS              BAMLHE00EHYIOAS     2022-09-09   2022-09-09
# BAMLHE00EHYIEY                BAMLHE00EHYIEY     2022-09-09   2022-09-09
# MORTGAGE5US                      MORTGAGE5US     2022-09-09   2022-09-09
# BAMLHYH0A0HYM2TRIV        BAMLHYH0A0HYM2TRIV     2022-09-09   2022-09-09
# BAMLC0A0CMEY                    BAMLC0A0CMEY     2022-09-09   2022-09-09
# ...
